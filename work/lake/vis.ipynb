# %%
from work.lake.main import (
    run_training,
    explain_with_all_supported_methods,
)


ARTIFACTS_PATH = "output/lake_oxygen_artifacts.joblib"

# explain first test example for that depth
explain_with_all_supported_methods(
    artifacts_path=ARTIFACTS_PATH,
    example_index=1,
)
# Out:
# c:\Users\janav\Documents\projects\xai-sandbox\.venv\Lib\site-packages\captum\attr\_core\deep_lift.py:304: UserWarning: Setting forward, backward hooks and attributes on non-linear
#                activations. The hooks and attributes will be removed
#             after the attribution is finished
#   warnings.warn(

# %%
explain_with_all_supported_methods(
    artifacts_path=ARTIFACTS_PATH,
    example_index=39,
)
# Out:
# c:\Users\janav\Documents\projects\xai-sandbox\.venv\Lib\site-packages\captum\attr\_core\deep_lift.py:304: UserWarning: Setting forward, backward hooks and attributes on non-linear
#                activations. The hooks and attributes will be removed
#             after the attribution is finished
#   warnings.warn(
